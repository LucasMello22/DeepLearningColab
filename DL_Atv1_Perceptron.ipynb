# %%
# !git clone https://github.com/filiperobotic/DL_Mestrado.git
# Out:
# Cloning into 'DL_Mestrado'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 212 (delta 41), reused 98 (delta 37), pack-reused 103
# Receiving objects: 100% (212/212), 5.56 MiB | 29.66 MiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#Some helper functions for plotting and drawing lines

def plot_points(X, y):
    admitted = X[np.argwhere(y==1)]
    rejected = X[np.argwhere(y==0)]
    plt.scatter([s[0][0] for s in rejected], [s[0][1] for s in rejected], s = 25, color = 'blue', edgecolor = 'k')
    plt.scatter([s[0][0] for s in admitted], [s[0][1] for s in admitted], s = 25, color = 'red', edgecolor = 'k')

def display(m, b, color='g--'):
    plt.xlim(-0.05,1.05)
    plt.ylim(-0.05,1.05)
    x = np.arange(-10, 10, 0.1)
    plt.plot(x, m*x+b, color)

# %% [markdown]
# ## Lendo os dados

# %%
data = pd.read_csv('DL_Mestrado/data.csv', header=None)
X = np.array(data[[0,1]])
y = np.array(data[2])
plot_points(X,y)
plt.show()

# %% [markdown]
# ## Construindo o Perceptron

# %%
def perceptron(X, y,  eta, epochs):


  # initialize the weight matrix and store the learning rate
  N = X.shape[1] #number of inputs
  W = np.random.randn(N + 1) / np.sqrt(N)

  # insert a column of 1's as the last entry in the feature
  # matrix -- this little trick allows us to treat the bias
  # as a trainable parameter within the weight matrix
  X = np.c_[X, np.ones((X.shape[0]))]

  # loop over the desired number of epochs
  for epoch in np.arange(0, epochs):
    # loop over each individual data point
    for (x, training) in zip(X, y):

      #TODO

  # compute the dot product between the input features
  # and the weight matrix, then pass this value
  # through the step function to obtain the prediction
      prediction = np.dot(x, W)

      if prediction > 0:
        prediction = 1
      else:
        prediction = 0

   # compute the error between the prediction and the true

      error = prediction - training

   # if the error is not 0, update the weight matrix

      if error != 0:
        W -= eta * error * x

  return W

# %%
weights = perceptron(X, y,  0.01, 100)

# Plotting the solution boundary
plt.title("Solution boundary")
display(-weights[0]/weights[1], -weights[2]/weights[1], 'Purple')

# Plotting the data
plot_points(X, y)
plt.show()
